# %% [markdown]
# # Strawberry Puree or no Strawberry Puree?
#
# ![image.png](attachment:image.png)
#
# Source: https://asu.quadram.ac.uk/example-datasets-for-download/

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
fp = pd.read_csv('../data/MIR_Fruit_purees.csv')

# %%
fp.sample(10)
# Out:
#      Wavenumbers  NON-Strawberry  NON-Strawberry.1  NON-Strawberry.2  \
# 16       961.087        0.003137          0.003802          0.002943
# 171     1559.385        0.001760          0.000255          0.001828
# 31      1018.987        0.007995          0.010727          0.008778
# 192     1640.445        0.001175         -0.000453          0.001761
# 72      1177.246        0.004309          0.004516          0.003837
# 70      1169.526        0.004398          0.005218          0.003982
# 71      1173.386        0.004287          0.004744          0.003841
# 106     1308.486        0.004874          0.003795          0.004536
# 189     1628.865        0.001409         -0.000717          0.001972
# 120     1362.526        0.005484          0.004722          0.005192
#
#      NON-Strawberry.3  NON-Strawberry.4  NON-Strawberry.5  NON-Strawberry.6  \
# 16           0.003025          0.002985          0.003121          0.002901
# 171          0.000868          0.000715          0.000702          0.000818
# 31           0.008985          0.008980          0.009977          0.008990
# 192          0.001596          0.001159          0.001139          0.001308
# 72           0.004365          0.004526          0.004172          0.004379
# 70           0.004390          0.004546          0.004377          0.004437
# 71           0.004297          0.004451          0.004183          0.004317
# 106          0.004841          0.004870          0.004566          0.004871
# 189          0.001327          0.000957          0.000921          0.001182
# 120          0.005260          0.005143          0.005198          0.005242
#
#      NON-Strawberry.7  NON-Strawberry.8         ...          \
# 16           0.002663          0.002909         ...
# 171          0.001030          0.000640         ...
# 31           0.007164          0.009079         ...
# 192          0.002300          0.001311         ...
# 72           0.004639          0.004385         ...
# 70           0.004303          0.004430         ...
# 71           0.004392          0.004321         ...
# 106          0.005355          0.004817         ...
# 189          0.002236          0.001065         ...
# 120          0.005357          0.005092         ...
#
#      NON-Strawberry.622  NON-Strawberry.623  NON-Strawberry.624  \
# 16             0.003259            0.003389            0.003421
# 171            0.000383            0.000080            0.000151
# 31             0.011817            0.012152            0.012504
# 192            0.000140           -0.000266           -0.000189
# 72             0.003838            0.003917            0.003621
# 70             0.004475            0.004552            0.004290
# 71             0.004033            0.004118            0.003830
# 106            0.004100            0.004077            0.003993
# 189            0.000068           -0.000343           -0.000326
# 120            0.005233            0.005148            0.005077
#
#      NON-Strawberry.625  NON-Strawberry.626  NON-Strawberry.627  \
# 16             0.003336            0.003458            0.003469
# 171            0.000256            0.000020            0.000105
# 31             0.012176            0.012642            0.012829
# 192           -0.000106           -0.000274           -0.000190
# 72             0.003805            0.003712            0.003650
# 70             0.004455            0.004385            0.004337
# 71             0.004014            0.003935            0.003876
# 106            0.004073            0.004026            0.003960
# 189           -0.000189           -0.000416           -0.000350
# 120            0.005167            0.005062            0.005043
#
#      NON-Strawberry.628  NON-Strawberry.629  NON-Strawberry.630  \
# 16             0.003517            0.003461            0.003791
# 171            0.000199            0.000129           -0.000542
# 31             0.012860            0.012555            0.014678
# 192           -0.000204           -0.000200           -0.000734
# 72             0.003172            0.003378            0.002707
# 70             0.003936            0.004059            0.003653
# 71             0.003437            0.003606            0.003061
# 106            0.003577            0.003756            0.003152
# 189           -0.000328           -0.000279           -0.000878
# 120            0.004690            0.004839            0.004277
#
#      NON-Strawberry.631
# 16             0.003778
# 171           -0.000532
# 31             0.014706
# 192           -0.000721
# 72             0.002694
# 70             0.003617
# 71             0.003040
# 106            0.003128
# 189           -0.000996
# 120            0.004255
#
# [10 rows x 984 columns]

# %%
fpt = fp.iloc[:,1:].transpose()
fpt.sample(10)
# Out:
#                          0         1         2         3         4    \
# NON-Strawberry.574  0.002299  0.002341  0.002397  0.002533  0.002836
# NON-Strawberry.216  0.002751  0.003034  0.003368  0.003822  0.004420
# NON-Strawberry.63   0.002922  0.002953  0.003064  0.003249  0.003507
# Strawberry.197      0.002436  0.002468  0.002559  0.002721  0.002957
# NON-Strawberry.50   0.001866  0.001869  0.001830  0.001832  0.001897
# NON-Strawberry.370  0.002133  0.002063  0.001989  0.002056  0.002192
# Strawberry.174      0.002880  0.002867  0.002848  0.002894  0.003056
# NON-Strawberry.527  0.002388  0.002349  0.002300  0.002360  0.002516
# Strawberry.314      0.002199  0.002206  0.002237  0.002346  0.002528
# Strawberry.97       0.002449  0.002499  0.002506  0.002657  0.002912
#
#                          5         6         7         8         9    \
# NON-Strawberry.574  0.003150  0.003340  0.003405  0.003361  0.003197
# NON-Strawberry.216  0.005176  0.005935  0.006418  0.006391  0.005979
# NON-Strawberry.63   0.003803  0.004052  0.004162  0.004085  0.003878
# Strawberry.197      0.003212  0.003414  0.003468  0.003369  0.003234
# NON-Strawberry.50   0.002000  0.002076  0.002072  0.002056  0.002077
# NON-Strawberry.370  0.002343  0.002404  0.002327  0.002219  0.002175
# Strawberry.174      0.003265  0.003385  0.003349  0.003222  0.003091
# NON-Strawberry.527  0.002683  0.002742  0.002676  0.002601  0.002566
# Strawberry.314      0.002723  0.002798  0.002755  0.002671  0.002597
# Strawberry.97       0.003137  0.003310  0.003324  0.003217  0.003085
#
#                       ...          225       226       227       228  \
# NON-Strawberry.574    ...     0.000273  0.000180  0.000111  0.000069
# NON-Strawberry.216    ...     0.000006 -0.000011 -0.000016 -0.000018
# NON-Strawberry.63     ...     0.000217  0.000120  0.000084  0.000084
# Strawberry.197        ...     0.000178  0.000115  0.000061  0.000034
# NON-Strawberry.50     ...     0.000799  0.000554  0.000355  0.000243
# NON-Strawberry.370    ...     0.000488  0.000331  0.000198  0.000129
# Strawberry.174        ...     0.000319  0.000225  0.000129  0.000081
# NON-Strawberry.527    ...     0.000471  0.000348  0.000229  0.000140
# Strawberry.314        ...     0.000195  0.000134  0.000073  0.000032
# Strawberry.97         ...     0.000161  0.000103  0.000057  0.000035
#
#                          229       230       231       232       233       234
# NON-Strawberry.574  0.000039  0.000027  0.000021  0.000019  0.000013  0.000013
# NON-Strawberry.216 -0.000020 -0.000012 -0.000005 -0.000004 -0.000003  0.000000
# NON-Strawberry.63   0.000066  0.000062  0.000029  0.000002  0.000004  0.000004
# Strawberry.197      0.000024  0.000018  0.000015  0.000014  0.000008  0.000008
# NON-Strawberry.50   0.000161  0.000105  0.000068  0.000034  0.000012  0.000012
# NON-Strawberry.370  0.000079  0.000055  0.000042  0.000023  0.000009  0.000009
# Strawberry.174      0.000052  0.000028  0.000024  0.000017  0.000012  0.000012
# NON-Strawberry.527  0.000092  0.000049  0.000046  0.000041  0.000013  0.000013
# Strawberry.314      0.000018  0.000012  0.000012  0.000014  0.000013  0.000013
# Strawberry.97       0.000020  0.000016  0.000015  0.000009  0.000007  0.000007
#
# [10 rows x 235 columns]

# %% [markdown]
# Next, we need to extract the label:
# - 1 for strawberry
# - 0 for other

# %%
fpt['strawberry'] = fpt.index
fpt['strawberry'] = ~fpt.strawberry.str.contains('NON')
fpt['strawberry'] = [1  if x else 0 for x in fpt.strawberry]
fpt.strawberry.value_counts()
# Out:
# 0    632
# 1    351
# Name: strawberry, dtype: int64

# %%
fpt.sample(5)
# Out:
#                            0         1         2         3         4  \
# NON-Strawberry.38   0.002065  0.002054  0.002096  0.002182  0.002374
# NON-Strawberry.319  0.002161  0.002120  0.002083  0.002129  0.002240
# Strawberry.277      0.002794  0.002854  0.002908  0.003013  0.003235
# NON-Strawberry.489  0.002294  0.002272  0.002257  0.002302  0.002415
# NON-Strawberry.423  0.002515  0.002522  0.002530  0.002630  0.002857
#
#                            5         6         7         8         9  \
# NON-Strawberry.38   0.002603  0.002737  0.002736  0.002686  0.002636
# NON-Strawberry.319  0.002399  0.002470  0.002399  0.002320  0.002299
# Strawberry.277      0.003502  0.003693  0.003751  0.003677  0.003522
# NON-Strawberry.489  0.002540  0.002577  0.002524  0.002490  0.002497
# NON-Strawberry.423  0.003073  0.003136  0.003078  0.002990  0.002896
#
#                        ...           226       227           228       229  \
# NON-Strawberry.38      ...      0.000295  0.000177  1.102500e-04  0.000072
# NON-Strawberry.319     ...      0.000420  0.000277  1.823140e-04  0.000120
# Strawberry.277         ...      0.000246  0.000164  9.624270e-05  0.000057
# NON-Strawberry.489     ...      0.000474  0.000329  2.355990e-04  0.000169
# NON-Strawberry.423     ...      0.000043  0.000014 -1.846250e-07 -0.000001
#
#                          230       231       232       233       234  \
# NON-Strawberry.38   0.000048  0.000032  0.000019  0.000010  0.000010
# NON-Strawberry.319  0.000072  0.000052  0.000036  0.000014  0.000014
# Strawberry.277      0.000029  0.000020  0.000020  0.000009  0.000009
# NON-Strawberry.489  0.000115  0.000081  0.000048  0.000020  0.000020
# NON-Strawberry.423  0.000004  0.000007  0.000010  0.000008  0.000000
#
#                     strawberry
# NON-Strawberry.38            0
# NON-Strawberry.319           0
# Strawberry.277               1
# NON-Strawberry.489           0
# NON-Strawberry.423           0
#
# [5 rows x 236 columns]

# %% [markdown]
# Plot the data...

# %%
x = fpt.iloc[:,:-1]
y = fpt.strawberry
x.sample(10).transpose().plot(figsize=(16,10));

# %% [markdown]
# # Simple Modeling
# Let's start by creating a simple Naive Bayes model...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
nb = GaussianNB()
cross_val_score(nb, x, y)
# Out:
# array([0.79573171, 0.83536585, 0.83180428])

# %%
y.value_counts()
# Out:
# 0    632
# 1    351
# Name: strawberry, dtype: int64

# %% [markdown]
# ## Confusion Matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=3)
nb.fit(x_train, y_train)
preds = nb.predict(x_test)
cm = confusion_matrix(preds, y_test)
print(classification_report(preds, y_test))
print(cm)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.95      0.87       121
#           1       0.94      0.77      0.85       125
#
# avg / total       0.87      0.86      0.86       246
#
# [[115   6]
#  [ 29  96]]

# %% [markdown]
# # Dimensionality Reduction
# The model above uses 235 dimensions. Looking at the graph every dimension is highly correlated to it's neighbors. So, do we really need so many dimensions to express all the information?
#
# **Meet the PCA!**

# %%
# Generate example data

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
from sklearn import svm
from sklearn.ensemble import IsolationForest

df = pd.DataFrame(np.random.randn(250, 2))
df[1] = df[0] + df[1] * 0.7

fix, ax = plt.subplots(figsize=(6,6))
plt.scatter(df[0], df[1], color='grey')
plt.xlabel('x_1')
plt.ylabel('x_2');

# %% [markdown]
# Most of the information in this data set is along a linear axis along the diagonal, so if we can somehow extract the direction of the main axis, we can express a huge part of the information with the position of the projection of the data onto this line.
#
# This is what the PCA can do for you!
#
# The PCA creates an axis transformation. It creates new axes, such that:
# - all new axes are orthogonal
# - each axis describes as much variance as possible
#
# Have a look at the result:

# %%
from sklearn.decomposition import PCA
pca = PCA(svd_solver='full')
fix, ax = plt.subplots(figsize=(6,6))
plt.scatter(df[0], df[1], color='grey')

pca.fit(df)
pca_score = pca.explained_variance_ratio_
pca_comp = (pca.components_)
plt.plot([0,pca_comp[0,0] * pca_score[0] / pca_score.min()],[0,pca_comp[0,1] * pca_score[0] / pca_score.min()])
plt.plot([0,pca_comp[1,0] * pca_score[1] / pca_score.min()],[0,pca_comp[1,1] * pca_score[1] / pca_score.min()])
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.xlim(-4,3)
plt.ylim(-4,3)
pca_comp
# Out:
# array([[-0.61215851, -0.79073507],
#        [-0.79073507,  0.61215851]])

# %% [markdown]
# And here is the data in the transformed space:

# %%
df_pca = pd.DataFrame(pca.transform(df))
fig, ax = plt.subplots(figsize=(6,6))
plt.scatter(df_pca[0], df_pca[1], color='grey')
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
plt.xlabel('pc_1')
plt.ylabel('pc_2')
plt.plot([0,1], [0,0])
plt.plot([0,0], [0,1])

# %% [markdown]
# Now we only need the first principal component (pc_1) to express most of the variance in the data. How much?

# %%
pca.explained_variance_ratio_
# Out:
# array([0.91153004, 0.08846996])

# %% [markdown]
# ## How does it work?
# The principal components produced by the PCA are the Eigenvectors of the covariance matrix.
#
# The explained variance of each component corresponds to the Eigenvalues of the covariance matrix.

# %% [markdown]
# # Modeling with PCA
#
# The PCA is availabe as `sklearn.decomposition.PCA`.
#
# When you use it, it's usually a good idea to standardize the data before the PCA. Otherwise, the features with the biggest scale are overweighted for their contribution to the variance.
#
# Usually, the PCA is used to reduce the dimensionality of the data. Usually, we specify that we want to keep a certain amount of explained variance. We then add principal components until the cumulative explained variance reaches the desired value.
#
# Let's take a look at our strawberry puree:

# %% [markdown]
# Imports:

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
pca = PCA(svd_solver='full')
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %% [markdown]
# Let's plot the cumulative explained variance:

# %%
plt.plot(pca.explained_variance_ratio_.cumsum());

# %% [markdown]
# The first few components explain almost all the variance. Let's zoom in to the first 10 components:

# %%
plt.plot(pca.explained_variance_ratio_[:10].cumsum());

# %% [markdown]
# We can tell the PCA to keep only the as many components as necessary to keep a certain amount of variance:

# %%
import seaborn as sns

pca = PCA(svd_solver='full', n_components=0.9)
pca.fit(x)
plt.plot(pca.explained_variance_ratio_.cumsum())

pca_df = pd.DataFrame(pca.transform(x))
pca_df['l'] = y.values
sns.pairplot(data=pca_df, hue='l');

# %% [markdown]
# When using the PCA in a validation, you may only use the training data to fit it. If you would use the full data set, information from the test data would leak into the model.
#
# So here's a pipeline with standard scaler, pca, naive bayes, and cross validation:

# %%
pipe = make_pipeline(StandardScaler(), pca, nb)
pipe.fit(x, y)

# print the results and the plot PCA
plt.plot(pca.explained_variance_ratio_.cumsum())
print('with PCA: ', cross_val_score(pipe, x, y))
print('without PCA: ', cross_val_score(nb, x, y));
# Out:
# with PCA:  [0.83231707 0.875      0.86238532]
# without PCA:  [0.79573171 0.83536585 0.83180428]

# %% [markdown]
# So, with only 4 dimensions our accuracy is better than when we use all 235 original dimensions!

# %% [markdown]
# # Exercice 1: Experimentation
# Still with the strawberry data, experiment with different settings.
# Ideas:
# - how does the amount of principal components affect the classification accuracy?
# - how does the PCA affect the classification accuracy when using different classification algorithms than Naive Bayes?

# %%
# your code here...

# %% [markdown]
# # Exercise 2: MAGIC
#
# Add the PCA to the analysis of the MAGIC data set.
# - does it improve the performance?
# - do you think the PCA is well suited for the data set? Why/why not?
#
# Import the data:

# %%
import pandas as pd

columns = ['fLength',
        'fWidth',
        'fSize',
        'fConc',
        'fConc1',
        'fAsym',
        'fM3Long',
        'fM3Trans',
        'fAlpha',
        'fDist',
        'class']

#data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data')
data = pd.read_csv('../data/MAGIC/magic04.data')
data.columns = columns

data.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 1  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 2   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 3   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
# 4   51.6240   21.1502  2.9085  0.2420  0.1340   50.8761  43.1887    9.8145
#
#     fAlpha    fDist class
# 0   6.3609  205.261     g
# 1  76.9600  256.788     g
# 2  10.4490  116.737     g
# 3   4.6480  356.462     g
# 4   3.6130  238.098     g

# %%
# your code here...
