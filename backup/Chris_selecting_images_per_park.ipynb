# %%
# # Installing missing libraries
# !conda install -c conda-forge fiona --yes ;
# !conda install -c conda-forge utm --yes;
# !conda install -c conda-forge googlemaps --yes;
# !conda install -c conda-forge geopy --yes;

import os
import sys


# add funciotns directory to system path
module_path = os.path.abspath(os.path.join('/home/gremlin/GGCW_tools_git/Functions')) 
if module_path not in sys.path:
    sys.path.append(module_path)

sys.path
# Out:
# ['',
#  '/anaconda/lib/python27.zip',
#  '/anaconda/lib/python2.7',
#  '/anaconda/lib/python2.7/plat-linux2',
#  '/anaconda/lib/python2.7/lib-tk',
#  '/anaconda/lib/python2.7/lib-old',
#  '/anaconda/lib/python2.7/lib-dynload',
#  '/anaconda/lib/python2.7/site-packages',
#  '/anaconda/lib/python2.7/site-packages/IPython/extensions',
#  '/home/gremlin/.ipython',
#  '/home/gremlin/GGCW_tools_git/Functions']

# %%
### home made functions
import nice_functions as nf

reload(nf)

import get_OSM_polygons as getOSM

reload(getOSM)

### other libraries
from collections import namedtuple

import pandas as pd
import numpy as np

from shapely.ops import transform
from shapely.geometry import mapping, Polygon, box, shape
import matplotlib.pyplot as plt

from matplotlib import pyplot
# %matplotlib inline

import random

import fiona

import pickle

from gbdxtools import Interface
from gbdxtools.task import env
from gbdxtools import CatalogImage

gbdx = Interface()

# %%
# function for calculating overlap 
def area_overlap(a, b):  # returns None if rectangles don't intersect
    dx = min(a.xmax, b.xmax) - max(a.xmin, b.xmin)
    dy = min(a.ymax, b.ymax) - max(a.ymin, b.ymin)
    if (dx>=0) and (dy>=0):
        return dx*dy

# %%
bbox_city = nf.get_city_bounding_box('amsterdam')


epsg = nf.get_projections_and_UTM(bbox_city)

# %%
multipolygon_type = pickle.load(open( "../Pickle/multipolygon_type.p", "rb" ))

bbox_wkt = box(*bbox_city).wkt

# %%
query = "(item_type:WV03_VNIR OR WV02)"
query += " AND NOT item_type:IDAHOImage AND item_type:DigitalGlobeProduct"   
results = gbdx.vectors.query(bbox_wkt, query,count = 1e5)

# %%
query = "(item_type:)" 
results = gbdx.vectors.query(bbox_wkt, query,count = 1e5)

# %%
results
# Out:
# [{u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/9/1',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MTI__20180109T114957_S20180109T110422_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.091211820593285,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 170.496090867954,
#     u'sunElevation_dbl': 75.3027133054149,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MTI__20180109T114957_A004410_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'ad3a21d8-5f09-5145-9dcc-843fef98f2a3',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-09T14:54:39.479Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-09T11:04:19.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/19/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180119T130005_S20180119T110351_N02.06',
#     u'cloudCover_int': 57,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.24648628986628,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 169.421861529133,
#     u'sunElevation_dbl': 73.6281388163482,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180119T130005_A004553_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'2a96ac95-dc9d-5b87-90ac-fe1aa6a7a53a',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-19T20:23:06.320Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-19T11:03:49.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/18/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180118T141214_S20180118T104524_N02.06',
#     u'cloudCover_int': 82,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 9.017730014357594,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 164.726906050484,
#     u'sunElevation_dbl': 74.5008091354902,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180118T141214_A013447_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'fbc3767a-c5e8-5baa-909b-3ebb69745612',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-18T18:18:41.871Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-18T10:43:51.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/18/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180118T141214_S20180118T104524_N02.06',
#     u'cloudCover_int': 85,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.108059265987983,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 164.673813708152,
#     u'sunElevation_dbl': 73.6316374220101,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180118T141214_A013447_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'a641aca9-e579-57fa-b47c-a44f4e1e5862',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-18T18:23:32.254Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-18T10:43:51.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/21/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180121T143420_S20180121T105428_N02.06',
#     u'cloudCover_int': 64,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 3.5089366311007995,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 166.80928180981,
#     u'sunElevation_dbl': 73.526042289795,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180121T143420_A013490_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'09f80f4b-f6e6-5211-b431-d1429eeb7256',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-21T18:48:44.777Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-21T10:53:41.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/21/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180121T143420_S20180121T105428_N02.06',
#     u'cloudCover_int': 38,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 5.062014069603864,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 166.761056339541,
#     u'sunElevation_dbl': 72.6492252187244,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180121T143420_A013490_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'c89cd0cf-c8f0-5c57-86f8-69b715678c4d',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-21T18:46:56.658Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-21T10:53:41.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/16/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MPS__20180116T130813_S20180116T105527_N02.06',
#     u'cloudCover_int': 29,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 3.5148675990012417,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 167.33482449533,
#     u'sunElevation_dbl': 74.5036442161041,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MPS__20180116T130813_A004510_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'1b00e11e-71bb-5ebc-9900-baae632eadde',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-16T17:03:36.669Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-16T10:53:59.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/16/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MPS__20180116T130813_S20180116T105527_N02.06',
#     u'cloudCover_int': 40,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 5.075111892049533,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 167.292563789026,
#     u'sunElevation_dbl': 73.6250551170848,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MPS__20180116T130813_A004510_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'812df74f-845a-5881-b55e-8aa400501c89',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-16T17:48:38.975Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-16T10:53:59.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/14/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_MPS__20180114T131458_S20180114T110409_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.245673701386607,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 169.943010844716,
#     u'sunElevation_dbl': 74.5518179686299,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_MPS__20180114T131458_A013390_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'fa621897-12ef-5d8f-9074-9df49e854851',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-14T16:52:36.620Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-14T11:04:11.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/6/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180106T125114_S20180106T105424_N02.06',
#     u'cloudCover_int': 94,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 5.075522193577635,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 168.452505781305,
#     u'sunElevation_dbl': 75.0558467522914,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180106T125114_A004367_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'1c268a25-11d6-5b80-9d86-c1449b733897',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-06T15:56:39.521Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-06T10:54:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/6/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180106T125114_S20180106T105424_N02.06',
#     u'cloudCover_int': 99,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 3.5139156845681216,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 168.485124963306,
#     u'sunElevation_dbl': 75.9380439981305,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180106T125114_A004367_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'51a918da-5854-5ea7-90c5-a5684c36fced',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-06T15:57:38.064Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-06T10:54:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/3/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MPS__20180103T132536_S20180103T104424_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.103250957890928,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 166.465598815245,
#     u'sunElevation_dbl': 75.6733762720763,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MPS__20180103T132536_A004324_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'b02874dc-0066-5e1d-85e0-dc90b86ca29a',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-03T18:08:30.948Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-03T10:44:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/3/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MPS__20180103T132536_S20180103T104424_N02.06',
#     u'cloudCover_int': 95,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 9.010451537847576,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 166.50322127055,
#     u'sunElevation_dbl': 76.549213011321,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MPS__20180103T132536_A004324_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'a05357ea-6b35-508e-97d8-6e8b2a903b97',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-03T18:07:23.731Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-03T10:44:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/8/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180108T124506_S20180108T104415_N02.06',
#     u'cloudCover_int': 39,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.07846211453143,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 165.855859655676,
#     u'sunElevation_dbl': 75.1732305415138,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180108T124506_A013304_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'3bd5d08f-e60e-5228-8deb-f6fd136e6523',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-08T16:46:04.932Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-08T10:44:21.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/8/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180108T124506_S20180108T104415_N02.06',
#     u'cloudCover_int': 0,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.96943453290702,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 165.897752197739,
#     u'sunElevation_dbl': 76.0468909728262,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180108T124506_A013304_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'f33a3c94-8bc0-57f3-99ae-6469e919cb96',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-08T16:50:06.016Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-08T10:44:21.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/9/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_MPS__20180109T112254_S20180109T110603_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.443784399131761,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 170.496090867954,
#     u'sunElevation_dbl': 75.302713305415,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_MPS__20180109T112254_A004410_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'395b966a-c3ab-5b7e-8942-fc174177604a',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-09T13:07:37.275Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-09T11:04:19.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/13/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180113T124039_S20180113T104403_N02.06',
#     u'cloudCover_int': 93,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.1034052815013,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 165.251315447629,
#     u'sunElevation_dbl': 74.4910041339212,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180113T124039_A004467_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'e9d090ec-af39-5465-b3d4-f3230be17cb1',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-13T15:48:35.742Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-13T10:44:09.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/13/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180113T124039_S20180113T104403_N02.06',
#     u'cloudCover_int': 96,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 9.002764986679672,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 165.298353155688,
#     u'sunElevation_dbl': 75.3624152864952,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180113T124039_A004467_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'f58545bc-fa93-55a4-8135-b0667a20cfbd',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-13T15:53:20.783Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-13T10:44:09.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/24/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180124T130304_S20180124T110332_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.25558673154023,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 168.952476845556,
#     u'sunElevation_dbl': 72.5398945338609,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180124T130304_A013533_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'0dc77fcb-5b62-5db9-bd4a-c690b8d08d09',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-24T15:29:16.577Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-24T11:03:31.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/4/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180104T130839_S20180104T110452_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.279962442925374,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 171.082011166095,
#     u'sunElevation_dbl': 75.8719177576296,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180104T130839_A013247_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'011c3a48-734b-5068-b4e4-84350c3e793c',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-04T23:43:30.153Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-04T11:04:31.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/1/1/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180101T124911_S20180101T105435_N02.06',
#     u'cloudCover_int': 68,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 5.100003472953361,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 169.066677052171,
#     u'sunElevation_dbl': 75.4957355232554,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180101T124911_A013204_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'1ae5baa0-b2c0-5141-bac1-036847b5a423',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-01T16:11:01.296Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-01T10:54:41.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/1/1/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_SGS__20180101T124911_S20180101T105435_N02.06',
#     u'cloudCover_int': 52,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 3.5377509072371955,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 169.095527094316,
#     u'sunElevation_dbl': 76.3797019594068,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_SGS__20180101T124911_A013204_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'01c76523-89b0-5437-80a7-eb4860d481e6',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisitionsvc'},
#    u'ingest_date': u'2018-01-01T16:25:21.393Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-01-01T10:54:41.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[6.071679540593987, 53.24020834570321],
#      [6.071679540593987, 52.222566040961574],
#      [4.498460539188841, 52.222566040961574],
#      [4.498460539188841, 53.24020834570321],
#      [6.071679540593987, 53.24020834570321]]],
#    u'type': u'Polygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2016/4/4/0',
# ...
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'95ec5fc1-0735-5379-99b3-b459df589152',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-01T21:22:18.296Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-01T10:50:31.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/4/4/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_MTI__20180404T113451_S20180404T110249_N02.06',
#     u'cloudCover_int': 100,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 11.270289524297377,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 168.003505291352,
#     u'sunElevation_dbl': 47.5307503582429,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_MTI__20180404T113451_A014534_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'342c877f-27bb-5ce4-a295-b4af971a703b',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-04T22:53:43.548Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-04T10:56:21.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/4/3/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_EPAE_20180403T132754_S20180403T104105_N02.06',
#     u'cloudCover_int': 76,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 9.0034065677468,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 161.396557661811,
#     u'sunElevation_dbl': 48.7232921601709,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_EPAE_20180403T132754_A005611_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'b56a3ceb-cffd-53f6-8362-e9ba09f47a74',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-05T11:15:40.399Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-03T10:40:19.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/4/3/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_EPAE_20180403T132754_S20180403T104105_N02.06',
#     u'cloudCover_int': 55,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.104980252637043,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 161.159465180921,
#     u'sunElevation_dbl': 47.8692439253973,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_EPAE_20180403T132754_A005611_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'7c095575-6c68-5c54-8827-59b3ec64000a',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-05T04:16:55.906Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-03T10:40:19.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/4/6/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180406T125448_S20180406T105331_N02.06',
#     u'cloudCover_int': 93,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 3.515564688906053,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 164.70018667516,
#     u'sunElevation_dbl': 47.1195223732843,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180406T125448_A005654_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'5eb85502-0cf0-56c7-85c2-feb5a0959001',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-07T05:44:14.508Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-06T10:50:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/4/6/0',
#     u'catalogID': u'S2B_OPER_MSI_L1C_DS_SGS__20180406T125448_S20180406T105331_N02.06',
#     u'cloudCover_int': 58,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 5.081946971988429,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 164.494915594542,
#     u'sunElevation_dbl': 46.2508154617304,
#     u'tileId': u'S2B_OPER_MSI_L1C_TL_SGS__20180406T125448_A005654_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'3a11ef36-2df3-582e-8b56-2971691db0cd',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-07T05:45:13.274Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-06T10:50:29.027Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.071679540593987, 53.24020834570321],
#       [6.071679540593987, 52.222566040961574],
#       [4.498460539188841, 52.222566040961574],
#       [4.498460539188841, 53.24020834570321],
#       [6.071679540593987, 53.24020834570321]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FU/2018/4/8/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_MPS__20180408T124948_S20180408T104539_N02.06',
#     u'cloudCover_int': 45,
#     u'gridSquare': u'FU',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.978251005623518,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 161.390713690024,
#     u'sunElevation_dbl': 46.7958946847719,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_MPS__20180408T124948_A014591_T31UFU_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'2be06c9a-69dc-508b-98ba-d05718a7f8ee',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-09T03:40:07.385Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-08T10:40:21.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'},
#  {u'geometry': {u'coordinates': [[[[6.011255196474869, 52.341355093396764],
#       [6.011255196474869, 51.32452335475141],
#       [4.4678842661351155, 51.32452335475141],
#       [4.4678842661351155, 52.341355093396764],
#       [6.011255196474869, 52.341355093396764]]]],
#    u'type': u'MultiPolygon'},
#   u'properties': {u'attributes': {u'bandsList': [u'CoastalAerosol',
#      u'Blue',
#      u'Green',
#      u'Red',
#      u'VegRedEdge5',
#      u'VegRedEdge6',
#      u'VegRedEdge7',
#      u'NIR',
#      u'VegRedEdge8a',
#      u'WaterVapor',
#      u'Cirrus',
#      u'SWIR11',
#      u'SWIR12'],
#     u'browseJpgFile': u'preview.jpg',
#     u'bucketName': u'sentinel-s2-l1c',
#     u'bucketPrefix': u'tiles/31/U/FT/2018/4/8/0',
#     u'catalogID': u'S2A_OPER_MSI_L1C_DS_MPS__20180408T124948_S20180408T104539_N02.06',
#     u'cloudCover_int': 31,
#     u'gridSquare': u'FT',
#     u'imageFile': u'preview.jpg',
#     u'latitudeBand': u'U',
#     u'offNadirAngle_dbl': 8.082166300651608,
#     u'part_int': 0,
#     u'platformName': u'SENTINEL2',
#     u'productLevel': u'Level-1C',
#     u'resolution_dbl': [60.0,
#      10.0,
#      10.0,
#      10.0,
#      20.0,
#      20.0,
#      20.0,
#      10.0,
#      20.0,
#      60.0,
#      60.0,
#      20.0,
#      20.0],
#     u's3Region': u'eu-central-1',
#     u'sensorPlatformName': u'SENTINEL2',
#     u'sunAzimuth_dbl': 161.136043832956,
#     u'sunElevation_dbl': 45.9419148294489,
#     u'tileId': u'S2A_OPER_MSI_L1C_TL_MPS__20180408T124948_A014591_T31UFT_N02.06',
#     u'utmSequenceNumber': u'N',
#     u'utmZone_int': 31,
#     u'vendor': u'ESA',
#     u'vendorID': u'ESA',
#     u'xmlFile': u'metadata.xml'},
#    u'format': None,
#    u'id': u'bf8b448e-c866-5e89-ad52-359d77d1f3c3',
#    u'ingest_attributes': {u'_rest_url': u'http://vector.geobigdata.io/api/vectors/gbdx-alpha-catalog-v2-%257Bitem_date%253Ayyyy%257D',
#     u'_rest_user': u'acquisition-gbdx-support@digitalglobe.com'},
#    u'ingest_date': u'2018-04-09T04:40:25.964Z',
#    u'ingest_source': u'GBDX_INGEST_ALPHA',
#    u'item_date': u'2018-04-08T10:40:21.026Z',
#    u'item_type': [u'GBDXCatalogRecord', u'ESAProduct', u'SENTINEL2'],
#    u'name': None,
#    u'original_crs': u'EPSG:4326',
#    u'source': u'Sentinel',
#    u'text': u''},
#   u'type': u'Feature'}]

# %%
# query images that cover the park
# query = "(item_type:WV03_VNIR OR WV02 OR QB02 OR GE01)"


# calculate the overlap between image and park

Rectangle = namedtuple('Rectangle', 'xmin ymin xmax ymax')

ra = Rectangle(bbox_city[0],bbox_city[1],bbox_city[2],bbox_city[3]) # set wgs park area in rectangle

total_area = ((ra.xmax-ra.xmin)*(ra.ymax-ra.ymin))



# create dataframe for image metadata
images_df = pd.DataFrame(columns=['id','month','year','type','resolution','cloud cover','overlap','check'])

i = 1

# loop over all found images and load metadata in dataframe
# also perform a test to find the right images
for r in results:
    props = r['properties']
    geom = r['geometry']

    coordinates_image = geom['coordinates'][0][0]
    df_overlap = pd.DataFrame.from_records(coordinates_image,columns = ['x','y'])

    rb = Rectangle(df_overlap.x.min(), df_overlap.y.min(), df_overlap.x.max(), df_overlap.y.max())



    total_overlap = area_overlap(ra, rb)

    if total_overlap is None:
        fraction_overlap = 0
    else:
        fraction_overlap = total_overlap/total_area
      
  

    images_df = images_df.append({'id': props['attributes']['catalogID'],'month':props['item_date'][5:7],'year':props['item_date'][0:4],
                   'type':props['item_type'][1],'resolution':props['attributes']['resolution_dbl'],
                   'cloud cover':props['attributes']['cloudCover_int'],'overlap': fraction_overlap,
                    # perform check on, cloud cover, month (summer), and overlap 
                    'check':props['attributes']['cloudCover_int'] < 10 and int(props['item_date'][5:7]) >= 5 and int(props['item_date'][5:7]) <= 11 and 
                   fraction_overlap >.05},ignore_index=True)


# select only the images that survive the test
selection_images = images_df.reset_index().loc[images_df.check == True]

# group by image id because 
selection_images =  selection_images.groupby(['id'],sort=['year','month'],as_index=False).first().sort_values(['year','month'], ascending=False).reset_index().drop('level_0', axis='columns')

# %%
selection_images
# Out:
#                   id  index month  year       type  resolution  cloud cover  \
# 0   103001006FD63D00    130    08  2017       WV02       2.277            5
# 1   103001006D79BB00    101    07  2017       WV02       1.896            3
# 2   1040010030B00E00     75    07  2017  WV03_VNIR       1.304            2
# 3   104001002BC52E00    227    05  2017  WV03_VNIR       1.544            0
# 4   103001005EA2BC00    232    09  2016       WV02       2.055            0
# 5   103005004DF8CF00    113    05  2016       WV02       0.636            0
# 6   103005004DF97900     17    05  2016       WV02       0.476            0
# 7   1030050045F94600     18    10  2015       WV02       2.482            0
# 8   1030050045F94700     29    10  2015       WV02       0.658            0
# 9   1040010013A34500     31    10  2015  WV03_VNIR       1.416            5
# 10  1030050044F92A00     46    09  2015       WV02       2.543            0
# 11  1030050044F92B00     30    09  2015       WV02       0.468            0
# 12  1030050045F8F100     20    09  2015       WV02       1.954            0
# 13  1030050045F8F200      0    09  2015       WV02       0.467            0
# 14  1030050045F8F400     15    09  2015       WV02       0.499            0
# 15  1030010034A0CD00    142    08  2014       WV02       0.496            2
# 16  1030050033F8C300    126    08  2014       WV02       2.210            0
# 17  1030050033F8C400    144    08  2014       WV02       0.594            5
# 18  1030050030F99900    182    07  2014       WV02       2.406            3
# 19  103001001C5C1300     79    11  2012       WV02       2.319            4
# 20  1030050008F96100    169    09  2010       WV02       1.948            9
#
#      overlap  check
# 0   0.089104   True
# 1   0.214433   True
# 2   0.418828   True
# 3   0.350534   True
# 4   0.123086   True
# 5   0.303847   True
# 6   0.150906   True
# 7   0.754107   True
# 8   0.154618   True
# 9   0.161332   True
# 10  0.620675   True
# 11  0.486656   True
# 12  0.435661   True
# 13  0.416309   True
# 14  0.295661   True
# 15  0.586626   True
# 16  0.057590   True
# 17  0.278420   True
# 18  0.176087   True
# 19  0.198627   True
# 20  0.087070   True

# %%
all_coords_df = pd.DataFrame(columns = ['x','y','i'])

for i in selection_images['index']:

    coordinates_image = results[i]['geometry']['coordinates'][0][0]

    df_overlap = pd.DataFrame.from_records(coordinates_image,columns = ['x','y'])
    
    df_overlap['i'] = i
    
    all_coords_df = all_coords_df.append(df_overlap)
    
    rb = Rectangle(df_overlap.x.min(), df_overlap.y.min(), df_overlap.x.max(), df_overlap.y.max())
    
    
    x,y = box(bbox_city[0],bbox_city[1],bbox_city[2],bbox_city[3]).exterior.xy
        

    x1,y1 = box(df_overlap.x.min(), df_overlap.y.min(), df_overlap.x.max(), df_overlap.y.max()).exterior.xy



    total_area = ((ra.xmax-ra.xmin)*(ra.ymax-ra.ymin))




    # calculate the overlap between image and park

    Rectangle = namedtuple('Rectangle', 'xmin ymin xmax ymax')

    ra = Rectangle(bbox_city[0],bbox_city[1],bbox_city[2],bbox_city[3])

    rb = Rectangle(min(x1),min(y1),max(x1),max(y1))



    fig = plt.figure(1, figsize=(5,5), dpi=90)
    ax = fig.add_subplot(111)
    ax.plot(x, y, color = 'red', alpha=0.2,
        linewidth=3, solid_capstyle='round', zorder=2)

    ax.plot(x1,y1, color='blue', alpha=0.09,
        linewidth=3, solid_capstyle='round', zorder=2)

    # ax.set_xlim([4.6, 5.2])
    # ax.set_ylim([52.2, 52.5])


    ax.plot()
    ax.set_title('overlap is: {}%'.format( str(round(area_overlap(a=ra,b=rb)/total_area,3)*100)))

# %%
all_coords_df
# Out:
#            x          y    i
# 0   4.794300  52.530959  130
# 1   5.088431  52.555681  130
# 2   5.088192  52.439353  130
# 3   4.794658  52.414267  130
# 4   4.794300  52.530959  130
# 0   4.979921  52.432772  101
# 1   5.226750  52.433099  101
# 2   5.226508  52.305434  101
# 3   4.980145  52.305228  101
# 4   4.979921  52.432772  101
# 0   4.780714  52.385726   75
# 1   4.982971  52.381906   75
# 2   4.982686  52.275327   75
# 3   4.781165  52.279006   75
# 4   4.780714  52.385726   75
# 0   4.687723  52.471120  227
# 1   4.920980  52.450994  227
# 2   4.919134  52.336365  227
# 3   4.689541  52.354927  227
# 4   4.687723  52.471120  227
# 0   4.748007  52.459060  232
# 1   5.017931  52.448512  232
# 2   5.017620  52.407466  232
# 3   4.748315  52.417500  232
# 4   4.748007  52.459060  232
# 0   4.762020  52.533885  113
# 1   5.094376  52.496475  113
# 2   5.099278  52.379630  113
# 3   4.765778  52.417882  113
# 4   4.762020  52.533885  113
# ..       ...        ...  ...
# 0   4.755587  52.397841  142
# 1   5.007661  52.401968  142
# 2   5.007603  52.285253  142
# 3   4.755949  52.281059  142
# 4   4.755587  52.397841  142
# 0   4.694771  52.536719  126
# 1   4.992071  52.553032  126
# 2   4.991458  52.435714  126
# 3   4.694485  52.419790  126
# 4   4.694771  52.536719  126
# 0   4.968878  52.399531  144
# 1   5.287366  52.426352  144
# 2   5.285677  52.308875  144
# 3   4.967759  52.282606  144
# 4   4.968878  52.399531  144
# 0   4.719680  52.307690  182
# 1   5.036608  52.277278  182
# 2   5.038438  52.148163  182
# 3   4.720548  52.179324  182
# 4   4.719680  52.307690  182
# 0   4.684856  52.509545   79
# 1   5.009955  52.516241   79
# 2   5.009655  52.401582   79
# 3   4.685908  52.394446   79
# 4   4.684856  52.509545   79
# 0   4.990526  52.333419  169
# 1   5.245201  52.336236  169
# 2   5.244606  52.208634  169
# 3   4.990864  52.205673  169
# 4   4.990526  52.333419  169
#
# [105 rows x 3 columns]

# %%
#create function for rewrite 

base_coords_x = min(np.concatenate([x,all_coords_df['x']])) 
base_coords_y = min(np.concatenate([y,all_coords_df['y']])) 

    


x_n = np.subtract(x, base_coords_x)
y_n = np.subtract(y, base_coords_y)





for i in np.unique(all_coords_df['i']):
    
    all_coords_df['x_n'] =   all_coords_df['x'] - base_coords_x
    all_coords_df['y_n'] =   all_coords_df['y'] - base_coords_y 
    
    
width  = int(max(np.concatenate([x_n,all_coords_df['x_n']])) * 1000)
height = int(max(np.concatenate([y_n,all_coords_df['y_n']])) * 1000)

# %%
def image_draw_thing(all_coords_df,subset,nr):

        x_min_2 = all_coords_df['x_n'][all_coords_df['i'] == subset[nr]].min()
        y_min_2 = all_coords_df['y_n'][all_coords_df['i'] == subset[nr]].min()
        x_max_2 = all_coords_df['x_n'][all_coords_df['i'] == subset[nr]].max()
        y_max_2 = all_coords_df['y_n'][all_coords_df['i'] == subset[nr]].max()

        x2,y2 = box(x_min_2, y_min_2, x_max_2, y_max_2).exterior.xy

        polygon2 = [(x2[i_1]*1000, y2[i_1]*1000) for i_1 in range(len(x2))]

        img2 = Image.new('L', (width, height), 0)

        ImageDraw.Draw(img2).polygon(polygon2, fill=1)
        
        b = np.asarray(img2)
        
        return b

# %%
from PIL import Image, ImageDraw
import copy

import time
start_time = time.time()



import itertools

i = 0

stuff = selection_images['index']
for L in range(1, 4 if len(stuff) > 4 else len(stuff)):
    for subset in itertools.combinations(stuff, L):
        
        

        polygon = [(x_n[i_1]*1000, y_n[i_1]*1000) for i_1 in range(len(x_n))]

        
        b = image_draw_thing(all_coords_df,subset,0)
        



        if L >= 2: 
            
            b1 = image_draw_thing(all_coords_df,subset,1)
                    
        if L >= 3: 
            
            b2 = image_draw_thing(all_coords_df,subset,2)
                        
        if L >= 4: 
            
            b3 = image_draw_thing(all_coords_df,subset,3)
            
            

        # convert polygon coordinates to raster/array values using ImageDraw
        img = Image.new('L', (width, height), 0)

        ImageDraw.Draw(img).polygon(polygon, fill=1)

        a = np.asarray(img)

        
        
        if L == 1:
            c = a+b
        elif L == 2:
            c = a+b+b1
        elif L == 3:
            c = a+b+b1+b2
        elif L == 4:
            c = a+b+b1+b2+b3
            
        
        
        total_overlap_perc = round(sum(sum((a == 1) & (c > 1)))/float(sum(sum((a == 1)))),3) *100
        
        total_double_overlap = round(sum(sum((a == 1) & (c > 2)))/float(sum(sum((a == 1)))),3) *100
        
        
#         print(str(total_overlap_perc) + '% total overlap ' + str(total_double_overlap) + '% double overlap, subset is: '+ str(subset))
#         print("--- %s seconds --- \r" % (time.time() - start_time))
        
        
        if (total_overlap_perc > 10) & (total_double_overlap < 10):

            fig = plt.figure(i, figsize=(5,5), dpi=90)
            ax = fig.add_subplot(111)

            ax.imshow(c)

            ax.set_title(str(subset) +' overlap is: ' + str(total_overlap_perc) + '% double overlap is: ' + str(total_double_overlap))

            plt.gca().invert_yaxis()

    #         print(str(L) + str(subset) +' overlap is: ' + str(total_overlap_perc) + '%')

        i = i + 1

# %% [markdown]
# # test cells

# %%
plt.imshow((a == 1)& (c > 1))

# %%
round(sum(sum((a == 1) & (c >= 1)))/float(width * height),5)
# Out:
# 0.33966

# %%
sum(sum((a == 1) & (c >= 1)))/float(width * height)
# Out:
# 0.33966033966033965

# %%
float(width * height)
# Out:
# 154154.0

# %%
stuff = selection_images['index']
for L in range(1, 5 if len(stuff) > 5 else len(stuff)):
  for subset in itertools.combinations(stuff, L):
    print(subset)
# Out:
# (37,)
# (49,)
# (98,)
# (58,)
# (69,)
# (68,)
# (72,)
# (66,)
# (76,)
# (85,)
# (37, 49)
# (37, 98)
# (37, 58)
# (37, 69)
# (37, 68)
# (37, 72)
# (37, 66)
# (37, 76)
# (37, 85)
# (49, 98)
# (49, 58)
# (49, 69)
# (49, 68)
# (49, 72)
# (49, 66)
# (49, 76)
# (49, 85)
# (98, 58)
# (98, 69)
# (98, 68)
# (98, 72)
# (98, 66)
# (98, 76)
# (98, 85)
# (58, 69)
# (58, 68)
# (58, 72)
# (58, 66)
# (58, 76)
# (58, 85)
# (69, 68)
# (69, 72)
# (69, 66)
# (69, 76)
# (69, 85)
# (68, 72)
# (68, 66)
# (68, 76)
# (68, 85)
# (72, 66)
# (72, 76)
# (72, 85)
# (66, 76)
# (66, 85)
# (76, 85)
# (37, 49, 98)
# (37, 49, 58)
# (37, 49, 69)
# (37, 49, 68)
# (37, 49, 72)
# (37, 49, 66)
# (37, 49, 76)
# (37, 49, 85)
# (37, 98, 58)
# (37, 98, 69)
# (37, 98, 68)
# (37, 98, 72)
# (37, 98, 66)
# (37, 98, 76)
# (37, 98, 85)
# (37, 58, 69)
# (37, 58, 68)
# (37, 58, 72)
# (37, 58, 66)
# (37, 58, 76)
# (37, 58, 85)
# (37, 69, 68)
# (37, 69, 72)
# (37, 69, 66)
# (37, 69, 76)
# (37, 69, 85)
# (37, 68, 72)
# (37, 68, 66)
# (37, 68, 76)
# (37, 68, 85)
# (37, 72, 66)
# (37, 72, 76)
# (37, 72, 85)
# (37, 66, 76)
# (37, 66, 85)
# (37, 76, 85)
# (49, 98, 58)
# (49, 98, 69)
# (49, 98, 68)
# (49, 98, 72)
# (49, 98, 66)
# (49, 98, 76)
# (49, 98, 85)
# (49, 58, 69)
# (49, 58, 68)
# (49, 58, 72)
# (49, 58, 66)
# (49, 58, 76)
# (49, 58, 85)
# (49, 69, 68)
# (49, 69, 72)
# (49, 69, 66)
# (49, 69, 76)
# (49, 69, 85)
# (49, 68, 72)
# (49, 68, 66)
# (49, 68, 76)
# (49, 68, 85)
# (49, 72, 66)
# (49, 72, 76)
# (49, 72, 85)
# (49, 66, 76)
# (49, 66, 85)
# (49, 76, 85)
# (98, 58, 69)
# (98, 58, 68)
# (98, 58, 72)
# (98, 58, 66)
# (98, 58, 76)
# (98, 58, 85)
# (98, 69, 68)
# (98, 69, 72)
# (98, 69, 66)
# (98, 69, 76)
# (98, 69, 85)
# (98, 68, 72)
# (98, 68, 66)
# (98, 68, 76)
# (98, 68, 85)
# (98, 72, 66)
# (98, 72, 76)
# (98, 72, 85)
# (98, 66, 76)
# (98, 66, 85)
# (98, 76, 85)
# (58, 69, 68)
# (58, 69, 72)
# (58, 69, 66)
# (58, 69, 76)
# (58, 69, 85)
# (58, 68, 72)
# (58, 68, 66)
# (58, 68, 76)
# (58, 68, 85)
# (58, 72, 66)
# (58, 72, 76)
# (58, 72, 85)
# (58, 66, 76)
# (58, 66, 85)
# (58, 76, 85)
# (69, 68, 72)
# (69, 68, 66)
# (69, 68, 76)
# (69, 68, 85)
# (69, 72, 66)
# (69, 72, 76)
# (69, 72, 85)
# (69, 66, 76)
# (69, 66, 85)
# (69, 76, 85)
# (68, 72, 66)
# (68, 72, 76)
# (68, 72, 85)
# (68, 66, 76)
# (68, 66, 85)
# (68, 76, 85)
# (72, 66, 76)
# (72, 66, 85)
# (72, 76, 85)
# (66, 76, 85)
# (37, 49, 98, 58)
# (37, 49, 98, 69)
# (37, 49, 98, 68)
# (37, 49, 98, 72)
# (37, 49, 98, 66)
# (37, 49, 98, 76)
# (37, 49, 98, 85)
# (37, 49, 58, 69)
# (37, 49, 58, 68)
# (37, 49, 58, 72)
# (37, 49, 58, 66)
# (37, 49, 58, 76)
# (37, 49, 58, 85)
# (37, 49, 69, 68)
# (37, 49, 69, 72)
# (37, 49, 69, 66)
# (37, 49, 69, 76)
# (37, 49, 69, 85)
# (37, 49, 68, 72)
# (37, 49, 68, 66)
# (37, 49, 68, 76)
# (37, 49, 68, 85)
# (37, 49, 72, 66)
# (37, 49, 72, 76)
# (37, 49, 72, 85)
# (37, 49, 66, 76)
# (37, 49, 66, 85)
# (37, 49, 76, 85)
# (37, 98, 58, 69)
# (37, 98, 58, 68)
# (37, 98, 58, 72)
# (37, 98, 58, 66)
# (37, 98, 58, 76)
# (37, 98, 58, 85)
# (37, 98, 69, 68)
# (37, 98, 69, 72)
# (37, 98, 69, 66)
# (37, 98, 69, 76)
# (37, 98, 69, 85)
# (37, 98, 68, 72)
# (37, 98, 68, 66)
# (37, 98, 68, 76)
# (37, 98, 68, 85)
# (37, 98, 72, 66)
# (37, 98, 72, 76)
# (37, 98, 72, 85)
# (37, 98, 66, 76)
# (37, 98, 66, 85)
# (37, 98, 76, 85)
# (37, 58, 69, 68)
# (37, 58, 69, 72)
# (37, 58, 69, 66)
# (37, 58, 69, 76)
# (37, 58, 69, 85)
# (37, 58, 68, 72)
# (37, 58, 68, 66)
# (37, 58, 68, 76)
# (37, 58, 68, 85)
# (37, 58, 72, 66)
# (37, 58, 72, 76)
# (37, 58, 72, 85)
# (37, 58, 66, 76)
# (37, 58, 66, 85)
# (37, 58, 76, 85)
# (37, 69, 68, 72)
# (37, 69, 68, 66)
# (37, 69, 68, 76)
# (37, 69, 68, 85)
# (37, 69, 72, 66)
# (37, 69, 72, 76)
# (37, 69, 72, 85)
# (37, 69, 66, 76)
# (37, 69, 66, 85)
# (37, 69, 76, 85)
# (37, 68, 72, 66)
# (37, 68, 72, 76)
# (37, 68, 72, 85)
# (37, 68, 66, 76)
# (37, 68, 66, 85)
# (37, 68, 76, 85)
# (37, 72, 66, 76)
# (37, 72, 66, 85)
# (37, 72, 76, 85)
# (37, 66, 76, 85)
# (49, 98, 58, 69)
# (49, 98, 58, 68)
# (49, 98, 58, 72)
# (49, 98, 58, 66)
# (49, 98, 58, 76)
# (49, 98, 58, 85)
# (49, 98, 69, 68)
# (49, 98, 69, 72)
# (49, 98, 69, 66)
# (49, 98, 69, 76)
# (49, 98, 69, 85)
# (49, 98, 68, 72)
# (49, 98, 68, 66)
# (49, 98, 68, 76)
# (49, 98, 68, 85)
# (49, 98, 72, 66)
# (49, 98, 72, 76)
# (49, 98, 72, 85)
# (49, 98, 66, 76)
# (49, 98, 66, 85)
# (49, 98, 76, 85)
# (49, 58, 69, 68)
# (49, 58, 69, 72)
# (49, 58, 69, 66)
# (49, 58, 69, 76)
# (49, 58, 69, 85)
# (49, 58, 68, 72)
# (49, 58, 68, 66)
# (49, 58, 68, 76)
# (49, 58, 68, 85)
# (49, 58, 72, 66)
# (49, 58, 72, 76)
# (49, 58, 72, 85)
# (49, 58, 66, 76)
# (49, 58, 66, 85)
# (49, 58, 76, 85)
# (49, 69, 68, 72)
# (49, 69, 68, 66)
# (49, 69, 68, 76)
# (49, 69, 68, 85)
# (49, 69, 72, 66)
# (49, 69, 72, 76)
# (49, 69, 72, 85)
# (49, 69, 66, 76)
# (49, 69, 66, 85)
# (49, 69, 76, 85)
# (49, 68, 72, 66)
# (49, 68, 72, 76)
# (49, 68, 72, 85)
# (49, 68, 66, 76)
# (49, 68, 66, 85)
# (49, 68, 76, 85)
# (49, 72, 66, 76)
# (49, 72, 66, 85)
# (49, 72, 76, 85)
# (49, 66, 76, 85)
# (98, 58, 69, 68)
# (98, 58, 69, 72)
# (98, 58, 69, 66)
# (98, 58, 69, 76)
# (98, 58, 69, 85)
# (98, 58, 68, 72)
# (98, 58, 68, 66)
# (98, 58, 68, 76)
# (98, 58, 68, 85)
# (98, 58, 72, 66)
# (98, 58, 72, 76)
# (98, 58, 72, 85)
# (98, 58, 66, 76)
# (98, 58, 66, 85)
# (98, 58, 76, 85)
# (98, 69, 68, 72)
# (98, 69, 68, 66)
# (98, 69, 68, 76)
# (98, 69, 68, 85)
# (98, 69, 72, 66)
# (98, 69, 72, 76)
# (98, 69, 72, 85)
# (98, 69, 66, 76)
# (98, 69, 66, 85)
# (98, 69, 76, 85)
# (98, 68, 72, 66)
# (98, 68, 72, 76)
# (98, 68, 72, 85)
# (98, 68, 66, 76)
# (98, 68, 66, 85)
# (98, 68, 76, 85)
# (98, 72, 66, 76)
# (98, 72, 66, 85)
# (98, 72, 76, 85)
# (98, 66, 76, 85)
# (58, 69, 68, 72)
# (58, 69, 68, 66)
# (58, 69, 68, 76)
# (58, 69, 68, 85)
# (58, 69, 72, 66)
# (58, 69, 72, 76)
# (58, 69, 72, 85)
# (58, 69, 66, 76)
# (58, 69, 66, 85)
# (58, 69, 76, 85)
# (58, 68, 72, 66)
# (58, 68, 72, 76)
# (58, 68, 72, 85)
# (58, 68, 66, 76)
# (58, 68, 66, 85)
# (58, 68, 76, 85)
# (58, 72, 66, 76)
# (58, 72, 66, 85)
# (58, 72, 76, 85)
# (58, 66, 76, 85)
# (69, 68, 72, 66)
# (69, 68, 72, 76)
# (69, 68, 72, 85)
# (69, 68, 66, 76)
# (69, 68, 66, 85)
# (69, 68, 76, 85)
# (69, 72, 66, 76)
# (69, 72, 66, 85)
# (69, 72, 76, 85)
# (69, 66, 76, 85)
# (68, 72, 66, 76)
# (68, 72, 66, 85)
# (68, 72, 76, 85)
# (68, 66, 76, 85)
# (72, 66, 76, 85)

# %%
float(1000/10000)
# Out:
# 0.0

# %%
1./10.
# Out:
# 0.1
